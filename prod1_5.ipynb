# %% [markdown]
# # Examples
# ### 1
# Apply a production to a graph.

# %%
from hypergrammar.hypergraph import Hypergraph
from hypergrammar.edge import Edge, EdgeType
from hypergrammar.productions.prod_1 import Prod1

hg = Hypergraph()
hg.add_edge(Edge(EdgeType.E, frozenset({"A", "B"}), {"B": 1, "R": 0}))
hg.add_edge(Edge(EdgeType.E, frozenset({"B", "C"}), {"B": 0, "R": 0}))
hg.add_edge(Edge(EdgeType.E, frozenset({"C", "D"}), {"B": 1, "R": 0}))
hg.add_edge(Edge(EdgeType.E, frozenset({"D", "A"}), {"B": 0, "R": 0}))
hg.add_edge(Edge(EdgeType.Q, frozenset({"A", "B", "C", "D"}), {"R": 1}))

hg.set_vertex_parameter("A", {"x": 0, "y": 0})
hg.set_vertex_parameter("B", {"x": 1, "y": 0})
hg.set_vertex_parameter("C", {"x": 1, "y": 1})
hg.set_vertex_parameter("D", {"x": 0, "y": 1})

print("Before applying Prod1:")
hg.draw(use_positional_parameters=True)
# Out:
# Before applying Prod1:

# %%
prod1 = Prod1()
new_hg = prod1.apply(hg)
if new_hg:
    print(new_hg.get_edges())
    new_hg.draw(use_positional_parameters=True)
else:
    print("Production could not be applied.")
# Out:
# frozenset({Edge(type=EdgeType.E, vertices=frozenset({'C', 'D'}), parameters={'B': 1, 'R': 1}), Edge(type=EdgeType.E, vertices=frozenset({'B', 'C'}), parameters={'B': 0, 'R': 1}), Edge(type=EdgeType.E, vertices=frozenset({'A', 'D'}), parameters={'B': 0, 'R': 1}), Edge(type=EdgeType.E, vertices=frozenset({'B', 'A'}), parameters={'B': 1, 'R': 1}), Edge(type=EdgeType.Q, vertices=frozenset({'B', 'A', 'C', 'D'}), parameters={'R': 1})})

# %%
from hypergrammar.hypergraph import Hypergraph
from hypergrammar.edge import Edge, EdgeType
from hypergrammar.productions.prod_1 import Prod1

# Central vertex and intermediates from prod5 output
hg = Hypergraph()
# Original vertices
hg.set_vertex_parameter("A", {"x": 0, "y": 0})
hg.set_vertex_parameter("B", {"x": 1, "y": 0})
hg.set_vertex_parameter("C", {"x": 1, "y": 1})
hg.set_vertex_parameter("D", {"x": 0, "y": 1})
hg.set_vertex_parameter("X", {"x": 0.5, "y": 0})
hg.set_vertex_parameter("Y", {"x": 1, "y": 0.5})
hg.set_vertex_parameter("Z", {"x": 0.5, "y": 1})
hg.set_vertex_parameter("W", {"x": 0, "y": 0.5})
hg.set_vertex_parameter("M0", {"x": 0.5, "y": 0.5})

hg.add_edge(Edge(EdgeType.E, frozenset({"M0", "X"})))
hg.add_edge(Edge(EdgeType.E, frozenset({"M0", "Y"})))
hg.add_edge(Edge(EdgeType.E, frozenset({"M0", "Z"})))
hg.add_edge(Edge(EdgeType.E, frozenset({"M0", "W"})))

hg.add_edge(Edge(EdgeType.Q, frozenset({"M0", "W", "X", "A"}), {"R": 1}))  
hg.add_edge(Edge(EdgeType.Q, frozenset({"M0", "X", "Y", "B"}), {"R": 0}))
hg.add_edge(Edge(EdgeType.Q, frozenset({"M0", "Y", "Z", "C"}), {"R": 0}))
hg.add_edge(Edge(EdgeType.Q, frozenset({"M0", "Z", "W", "D"}), {"R": 0}))


hg.add_edge(Edge(EdgeType.E, frozenset({"A", "X"}), {"B": 1, "R": 0}))
hg.add_edge(Edge(EdgeType.E, frozenset({"X", "B"}), {"B": 1, "R": 0}))
hg.add_edge(Edge(EdgeType.E, frozenset({"B", "Y"}), {"B": 1, "R": 0}))
hg.add_edge(Edge(EdgeType.E, frozenset({"Y", "C"}), {"B": 1, "R": 0}))
hg.add_edge(Edge(EdgeType.E, frozenset({"C", "Z"}), {"B": 1, "R": 0}))
hg.add_edge(Edge(EdgeType.E, frozenset({"Z", "D"}), {"B": 1, "R": 0}))
hg.add_edge(Edge(EdgeType.E, frozenset({"D", "W"}), {"B": 1, "R": 0}))
hg.add_edge(Edge(EdgeType.E, frozenset({"W", "A"}), {"B": 1, "R": 0}))

hg.draw(use_positional_parameters=True)

# %%
prod1 = Prod1()
new_hg = prod1.apply(hg)
if new_hg:
    print(new_hg.get_edges())
    new_hg.draw(use_positional_parameters=True)
else:
    print("Production could not be applied.")
# Out:
# frozenset({Edge(type=EdgeType.Q, vertices=frozenset({'X', 'W', 'A', 'M0'}), parameters={'R': 1}), Edge(type=EdgeType.E, vertices=frozenset({'Y', 'C'}), parameters={'B': 1, 'R': 0}), Edge(type=EdgeType.E, vertices=frozenset({'D', 'W'}), parameters={'B': 1, 'R': 0}), Edge(type=EdgeType.E, vertices=frozenset({'Z', 'M0'}), parameters={}), Edge(type=EdgeType.E, vertices=frozenset({'X', 'A'}), parameters={'B': 1, 'R': 1}), Edge(type=EdgeType.Q, vertices=frozenset({'Y', 'B', 'X', 'M0'}), parameters={'R': 0}), Edge(type=EdgeType.Q, vertices=frozenset({'D', 'W', 'Z', 'M0'}), parameters={'R': 0}), Edge(type=EdgeType.E, vertices=frozenset({'B', 'X'}), parameters={'B': 1, 'R': 0}), Edge(type=EdgeType.E, vertices=frozenset({'Y', 'M0'}), parameters={}), Edge(type=EdgeType.E, vertices=frozenset({'W', 'M0'}), parameters={'R': 1}), Edge(type=EdgeType.Q, vertices=frozenset({'Y', 'Z', 'C', 'M0'}), parameters={'R': 0}), Edge(type=EdgeType.E, vertices=frozenset({'W', 'A'}), parameters={'B': 1, 'R': 1}), Edge(type=EdgeType.E, vertices=frozenset({'Y', 'B'}), parameters={'B': 1, 'R': 0}), Edge(type=EdgeType.E, vertices=frozenset({'Z', 'C'}), parameters={'B': 1, 'R': 0}), Edge(type=EdgeType.E, vertices=frozenset({'X', 'M0'}), parameters={'R': 1}), Edge(type=EdgeType.E, vertices=frozenset({'D', 'Z'}), parameters={'B': 1, 'R': 0})})

# %%
from hypergrammar.hypergraph import Hypergraph
from hypergrammar.edge import Edge, EdgeType
from hypergrammar.productions.prod_5 import Prod5

# Vertices: A, B, C, D; intermediates: X, Y, Z, W
# Each E edge is 'broken' via an intermediate
hg = Hypergraph()
hg.add_edge(Edge(EdgeType.E, frozenset({"A", "X"}), {"B": 1}))
hg.add_edge(Edge(EdgeType.E, frozenset({"X", "B"}), {"B": 1}))
hg.add_edge(Edge(EdgeType.E, frozenset({"B", "Y"}), {"B": 1}))
hg.add_edge(Edge(EdgeType.E, frozenset({"Y", "C"}), {"B": 1}))
hg.add_edge(Edge(EdgeType.E, frozenset({"C", "Z"}), {"B": 1}))
hg.add_edge(Edge(EdgeType.E, frozenset({"Z", "D"}), {"B": 1}))
hg.add_edge(Edge(EdgeType.E, frozenset({"D", "W"}), {"B": 1}))
hg.add_edge(Edge(EdgeType.E, frozenset({"W", "A"}), {"B": 1}))
hg.add_edge(Edge(EdgeType.Q, frozenset({"A", "B", "C", "D"}), {"R": 1}))

# Optionally set coordinates for visualization
hg.set_vertex_parameter("A", {"x": 0, "y": 0})
hg.set_vertex_parameter("B", {"x": 1, "y": 0})
hg.set_vertex_parameter("C", {"x": 1, "y": 1})
hg.set_vertex_parameter("D", {"x": 0, "y": 1})
hg.set_vertex_parameter("X", {"x": 0.5, "y": 0})
hg.set_vertex_parameter("Y", {"x": 1, "y": 0.5})
hg.set_vertex_parameter("Z", {"x": 0.5, "y": 1})
hg.set_vertex_parameter("W", {"x": 0, "y": 0.5})

print("Before applying Prod5:")
hg.draw(use_positional_parameters=True)
# Out:
# Before applying Prod5:

# %%
prod5 = Prod5()
new_hg = prod5.apply(hg)

print("After applying Prod5:")
if new_hg:
    new_hg.draw(use_positional_parameters=True)
else:
    print("Production could not be applied.")
# Out:
# Average x: 0.5
# Average y: 0.5
# After applying Prod5:

# %%
from hypergrammar.hypergraph import Hypergraph
from hypergrammar.edge import Edge, EdgeType
from hypergrammar.productions.prod_5 import Prod5


hg = Hypergraph()
hg.set_vertex_parameter("A", {"x": 0, "y": 0})
hg.set_vertex_parameter("B", {"x": 1, "y": 0})
hg.set_vertex_parameter("C", {"x": 1, "y": 1})
hg.set_vertex_parameter("D", {"x": 0, "y": 1})
hg.set_vertex_parameter("X", {"x": 0.5, "y": 0})
hg.set_vertex_parameter("Y", {"x": 1, "y": 0.5})
hg.set_vertex_parameter("Z", {"x": 0.5, "y": 1})
hg.set_vertex_parameter("W", {"x": 0, "y": 0.5})
hg.set_vertex_parameter("M0", {"x": 0.5, "y": 0.5})

hg.add_edge(Edge(EdgeType.E, frozenset({"M0", "X"})))
hg.add_edge(Edge(EdgeType.E, frozenset({"M0", "Y"})))
hg.add_edge(Edge(EdgeType.E, frozenset({"M0", "Z"})))
hg.add_edge(Edge(EdgeType.E, frozenset({"M0", "W"})))

hg.add_edge(Edge(EdgeType.Q, frozenset({"M0", "W", "X", "A"}), {"R": 1}))  
hg.add_edge(Edge(EdgeType.Q, frozenset({"M0", "X", "Y", "B"}), {"R": 0}))
hg.add_edge(Edge(EdgeType.Q, frozenset({"M0", "Y", "Z", "C"}), {"R": 0}))
hg.add_edge(Edge(EdgeType.Q, frozenset({"M0", "Z", "W", "D"}), {"R": 0}))


hg.add_edge(Edge(EdgeType.E, frozenset({"A", "X"}), {"B": 1, "R": 0}))
hg.add_edge(Edge(EdgeType.E, frozenset({"X", "B"}), {"B": 1, "R": 0}))
hg.add_edge(Edge(EdgeType.E, frozenset({"B", "Y"}), {"B": 1, "R": 0}))
hg.add_edge(Edge(EdgeType.E, frozenset({"Y", "C"}), {"B": 1, "R": 0}))
hg.add_edge(Edge(EdgeType.E, frozenset({"C", "Z"}), {"B": 1, "R": 0}))
hg.add_edge(Edge(EdgeType.E, frozenset({"Z", "D"}), {"B": 1, "R": 0}))
hg.add_edge(Edge(EdgeType.E, frozenset({"D", "W"}), {"B": 1, "R": 0}))
hg.add_edge(Edge(EdgeType.E, frozenset({"W", "A"}), {"B": 1, "R": 0}))

hg.draw(use_positional_parameters=True)
