# %% [markdown]
# # Examples
# ### 1
# Apply a production to a graph.

# %%
from hypergrammar.hypergraph import Hypergraph
from hypergrammar.edge import Edge, EdgeType
from hypergrammar.productions.prod_4 import Prod4


hg = Hypergraph()
hg.add_edge(Edge(EdgeType.E, frozenset({"A", "B"}), {"R": 1, "B": 1}))
hg.add_edge(Edge(EdgeType.E, frozenset({"B", "C"}), {"R": 1, "B": 1}))
hg.add_edge(Edge(EdgeType.E, frozenset({"C", "D"}), {"R": 1, "B": 1}))
hg.add_edge(Edge(EdgeType.E, frozenset({"D", "A"}), {"R": 1, "B": 1}))
hg.add_edge(Edge(EdgeType.Q, frozenset({"A", "B", "C", "D"}), {"R": 0}))

hg.set_vertex_parameter("A", {"x": 0, "y": 0})
hg.set_vertex_parameter("B", {"x": 1, "y": 0})
hg.set_vertex_parameter("C", {"x": 1, "y": 1})
hg.set_vertex_parameter("D", {"x": 0, "y": 1})

prod0 = Prod4()
new_hg = prod0.apply(hg)
if new_hg:
    print(new_hg.get_edges())
    new_hg.draw(use_positional_parameters=True)
else:
    print("Production could not be applied.")
# Out:
# frozenset({Edge(type=EdgeType.Q, vertices=frozenset({'A', 'B', 'D', 'C'}), parameters={'R': 0}), Edge(type=EdgeType.E, vertices=frozenset({'3534', 'A'}), parameters={'R': 0, 'B': 1}), Edge(type=EdgeType.E, vertices=frozenset({'3534', 'B'}), parameters={'R': 0, 'B': 1}), Edge(type=EdgeType.E, vertices=frozenset({'D', 'C'}), parameters={'R': 1, 'B': 1}), Edge(type=EdgeType.E, vertices=frozenset({'A', 'D'}), parameters={'R': 1, 'B': 1}), Edge(type=EdgeType.E, vertices=frozenset({'B', 'C'}), parameters={'R': 1, 'B': 1})})

# %%
new_hg = prod0.apply(new_hg)
if new_hg:
    print(new_hg.get_edges())
    new_hg.draw(use_positional_parameters=True)
else:
    print("Production could not be applied.")
# Out:
# frozenset({Edge(type=EdgeType.Q, vertices=frozenset({'A', 'B', 'D', 'C'}), parameters={'R': 0}), Edge(type=EdgeType.E, vertices=frozenset({'3534', 'A'}), parameters={'R': 0, 'B': 1}), Edge(type=EdgeType.E, vertices=frozenset({'3534', 'B'}), parameters={'R': 0, 'B': 1}), Edge(type=EdgeType.E, vertices=frozenset({'df84', 'C'}), parameters={'R': 0, 'B': 1}), Edge(type=EdgeType.E, vertices=frozenset({'A', 'D'}), parameters={'R': 1, 'B': 1}), Edge(type=EdgeType.E, vertices=frozenset({'df84', 'D'}), parameters={'R': 0, 'B': 1}), Edge(type=EdgeType.E, vertices=frozenset({'B', 'C'}), parameters={'R': 1, 'B': 1})})

# %%
new_hg = prod0.apply(new_hg)
if new_hg:
    print(new_hg.get_edges())
    new_hg.draw(use_positional_parameters=True)
else:
    print("Production could not be applied.")
# Out:
# frozenset({Edge(type=EdgeType.Q, vertices=frozenset({'A', 'B', 'D', 'C'}), parameters={'R': 0}), Edge(type=EdgeType.E, vertices=frozenset({'b081', 'D'}), parameters={'R': 0, 'B': 1}), Edge(type=EdgeType.E, vertices=frozenset({'3534', 'A'}), parameters={'R': 0, 'B': 1}), Edge(type=EdgeType.E, vertices=frozenset({'3534', 'B'}), parameters={'R': 0, 'B': 1}), Edge(type=EdgeType.E, vertices=frozenset({'df84', 'C'}), parameters={'R': 0, 'B': 1}), Edge(type=EdgeType.E, vertices=frozenset({'A', 'b081'}), parameters={'R': 0, 'B': 1}), Edge(type=EdgeType.E, vertices=frozenset({'df84', 'D'}), parameters={'R': 0, 'B': 1}), Edge(type=EdgeType.E, vertices=frozenset({'B', 'C'}), parameters={'R': 1, 'B': 1})})

# %%
new_hg = prod0.apply(new_hg)
if new_hg:
    print(new_hg.get_edges())
    new_hg.draw(use_positional_parameters=True)
else:
    print("Production could not be applied.")
# Out:
# frozenset({Edge(type=EdgeType.Q, vertices=frozenset({'A', 'B', 'D', 'C'}), parameters={'R': 0}), Edge(type=EdgeType.E, vertices=frozenset({'ca2b', 'B'}), parameters={'R': 0, 'B': 1}), Edge(type=EdgeType.E, vertices=frozenset({'3534', 'A'}), parameters={'R': 0, 'B': 1}), Edge(type=EdgeType.E, vertices=frozenset({'3534', 'B'}), parameters={'R': 0, 'B': 1}), Edge(type=EdgeType.E, vertices=frozenset({'df84', 'C'}), parameters={'R': 0, 'B': 1}), Edge(type=EdgeType.E, vertices=frozenset({'A', 'b081'}), parameters={'R': 0, 'B': 1}), Edge(type=EdgeType.E, vertices=frozenset({'b081', 'D'}), parameters={'R': 0, 'B': 1}), Edge(type=EdgeType.E, vertices=frozenset({'df84', 'D'}), parameters={'R': 0, 'B': 1}), Edge(type=EdgeType.E, vertices=frozenset({'ca2b', 'C'}), parameters={'R': 0, 'B': 1})})

# %%
new_hg = prod0.apply(new_hg)
if new_hg:
    print(new_hg.get_edges())
    new_hg.draw(use_positional_parameters=True)
else:
    print("Production could not be applied.")
# Out:
# Production could not be applied.
