# %% [markdown]
# # Examples
# ### 1
# Apply a production to a graph.

# %%
from hypergrammar.hypergraph import Hypergraph
from hypergrammar.edge import Edge, EdgeType
from hypergrammar.productions.prod_1 import Prod1

hg = Hypergraph()
hg.add_edge(Edge(EdgeType.E, frozenset({"A", "B"}), {"B": 1, "R": 0}))
hg.add_edge(Edge(EdgeType.E, frozenset({"B", "C"}), {"B": 0, "R": 0}))
hg.add_edge(Edge(EdgeType.E, frozenset({"C", "D"}), {"B": 1, "R": 0}))
hg.add_edge(Edge(EdgeType.E, frozenset({"D", "A"}), {"B": 0, "R": 0}))
hg.add_edge(Edge(EdgeType.Q, frozenset({"A", "B", "C", "D"}), {"R": 1}))

hg.set_vertex_parameter("A", {"x": 0, "y": 0})
hg.set_vertex_parameter("B", {"x": 1, "y": 0})
hg.set_vertex_parameter("C", {"x": 1, "y": 1})
hg.set_vertex_parameter("D", {"x": 0, "y": 1})

print("Before applying Prod1:")
hg.draw(use_positional_parameters=True)
# Out:
# Before applying Prod1:

# %%
prod1 = Prod1()
new_hg = prod1.apply(hg)
print("After applying Prod1:")
if new_hg:
    print(new_hg.get_edges())
    new_hg.draw(use_positional_parameters=True)
else:
    print("Production could not be applied.")
# Out:
# After applying Prod1:
# frozenset({Edge(type=EdgeType.E, vertices=frozenset({'B', 'A'}), parameters={'B': 1, 'R': 1}), Edge(type=EdgeType.E, vertices=frozenset({'A', 'D'}), parameters={'B': 0, 'R': 1}), Edge(type=EdgeType.E, vertices=frozenset({'B', 'C'}), parameters={'B': 0, 'R': 1}), Edge(type=EdgeType.E, vertices=frozenset({'C', 'D'}), parameters={'B': 1, 'R': 1}), Edge(type=EdgeType.Q, vertices=frozenset({'B', 'A', 'D', 'C'}), parameters={'R': 1})})

# %%
from hypergrammar.hypergraph import Hypergraph
from hypergrammar.edge import Edge, EdgeType
from hypergrammar.productions.prod_1 import Prod1

# Central vertex and intermediates from prod5 output
hg = Hypergraph()
# Original vertices
hg.set_vertex_parameter("A", {"x": 0, "y": 0})
hg.set_vertex_parameter("B", {"x": 1, "y": 0})
hg.set_vertex_parameter("C", {"x": 1, "y": 1})
hg.set_vertex_parameter("D", {"x": 0, "y": 1})
hg.set_vertex_parameter("X", {"x": 0.5, "y": 0})
hg.set_vertex_parameter("Y", {"x": 1, "y": 0.5})
hg.set_vertex_parameter("Z", {"x": 0.5, "y": 1})
hg.set_vertex_parameter("W", {"x": 0, "y": 0.5})
hg.set_vertex_parameter("M0", {"x": 0.5, "y": 0.5})

hg.add_edge(Edge(EdgeType.E, frozenset({"M0", "X"})))
hg.add_edge(Edge(EdgeType.E, frozenset({"M0", "Y"})))
hg.add_edge(Edge(EdgeType.E, frozenset({"M0", "Z"})))
hg.add_edge(Edge(EdgeType.E, frozenset({"M0", "W"})))

hg.add_edge(Edge(EdgeType.Q, frozenset({"M0", "W", "X", "A"}), {"R": 1}))  
hg.add_edge(Edge(EdgeType.Q, frozenset({"M0", "X", "Y", "B"}), {"R": 0}))
hg.add_edge(Edge(EdgeType.Q, frozenset({"M0", "Y", "Z", "C"}), {"R": 0}))
hg.add_edge(Edge(EdgeType.Q, frozenset({"M0", "Z", "W", "D"}), {"R": 0}))


hg.add_edge(Edge(EdgeType.E, frozenset({"A", "X"}), {"B": 1, "R": 0}))
hg.add_edge(Edge(EdgeType.E, frozenset({"X", "B"}), {"B": 1, "R": 0}))
hg.add_edge(Edge(EdgeType.E, frozenset({"B", "Y"}), {"B": 1, "R": 0}))
hg.add_edge(Edge(EdgeType.E, frozenset({"Y", "C"}), {"B": 1, "R": 0}))
hg.add_edge(Edge(EdgeType.E, frozenset({"C", "Z"}), {"B": 1, "R": 0}))
hg.add_edge(Edge(EdgeType.E, frozenset({"Z", "D"}), {"B": 1, "R": 0}))
hg.add_edge(Edge(EdgeType.E, frozenset({"D", "W"}), {"B": 1, "R": 0}))
hg.add_edge(Edge(EdgeType.E, frozenset({"W", "A"}), {"B": 1, "R": 0}))

print("Before applying Prod1:")
hg.draw(use_positional_parameters=True)
# Out:
# Before applying Prod1:

# %%
prod1 = Prod1()
new_hg = prod1.apply(hg)
print("After applying Prod5:")
if new_hg:
    print(new_hg.get_edges())
    new_hg.draw(use_positional_parameters=True)
else:
    print("Production could not be applied.")
# Out:
# After applying Prod5:
# frozenset({Edge(type=EdgeType.E, vertices=frozenset({'C', 'Y'}), parameters={'B': 1, 'R': 0}), Edge(type=EdgeType.E, vertices=frozenset({'B', 'X'}), parameters={'B': 1, 'R': 0}), Edge(type=EdgeType.E, vertices=frozenset({'A', 'W'}), parameters={'B': 1, 'R': 1}), Edge(type=EdgeType.E, vertices=frozenset({'M0', 'W'}), parameters={'R': 1}), Edge(type=EdgeType.Q, vertices=frozenset({'M0', 'Y', 'Z', 'C'}), parameters={'R': 0}), Edge(type=EdgeType.E, vertices=frozenset({'M0', 'Z'}), parameters={}), Edge(type=EdgeType.E, vertices=frozenset({'C', 'Z'}), parameters={'B': 1, 'R': 0}), Edge(type=EdgeType.E, vertices=frozenset({'D', 'Z'}), parameters={'B': 1, 'R': 0}), Edge(type=EdgeType.E, vertices=frozenset({'W', 'D'}), parameters={'B': 1, 'R': 0}), Edge(type=EdgeType.E, vertices=frozenset({'M0', 'X'}), parameters={'R': 1}), Edge(type=EdgeType.E, vertices=frozenset({'M0', 'Y'}), parameters={}), Edge(type=EdgeType.E, vertices=frozenset({'B', 'Y'}), parameters={'B': 1, 'R': 0}), Edge(type=EdgeType.Q, vertices=frozenset({'M0', 'D', 'W', 'Z'}), parameters={'R': 0}), Edge(type=EdgeType.E, vertices=frozenset({'X', 'A'}), parameters={'B': 1, 'R': 1}), Edge(type=EdgeType.Q, vertices=frozenset({'M0', 'X', 'A', 'W'}), parameters={'R': 1}), Edge(type=EdgeType.Q, vertices=frozenset({'M0', 'B', 'X', 'Y'}), parameters={'R': 0})})

# %%
from hypergrammar.hypergraph import Hypergraph
from hypergrammar.edge import Edge, EdgeType
from hypergrammar.productions.prod_5 import Prod5

# Vertices: A, B, C, D; intermediates: X, Y, Z, W
# Each E edge is 'broken' via an intermediate
hg = Hypergraph()
hg.add_edge(Edge(EdgeType.E, frozenset({"A", "X"}), {"B": 1}))
hg.add_edge(Edge(EdgeType.E, frozenset({"X", "B"}), {"B": 1}))
hg.add_edge(Edge(EdgeType.E, frozenset({"B", "Y"}), {"B": 1}))
hg.add_edge(Edge(EdgeType.E, frozenset({"Y", "C"}), {"B": 1}))
hg.add_edge(Edge(EdgeType.E, frozenset({"C", "Z"}), {"B": 1}))
hg.add_edge(Edge(EdgeType.E, frozenset({"Z", "D"}), {"B": 1}))
hg.add_edge(Edge(EdgeType.E, frozenset({"D", "W"}), {"B": 1}))
hg.add_edge(Edge(EdgeType.E, frozenset({"W", "A"}), {"B": 1}))
hg.add_edge(Edge(EdgeType.Q, frozenset({"A", "B", "C", "D"}), {"R": 1}))

# Optionally set coordinates for visualization
hg.set_vertex_parameter("A", {"x": 0, "y": 0})
hg.set_vertex_parameter("B", {"x": 1, "y": 0})
hg.set_vertex_parameter("C", {"x": 1, "y": 1})
hg.set_vertex_parameter("D", {"x": 0, "y": 1})
hg.set_vertex_parameter("X", {"x": 0.5, "y": 0})
hg.set_vertex_parameter("Y", {"x": 1, "y": 0.5})
hg.set_vertex_parameter("Z", {"x": 0.5, "y": 1})
hg.set_vertex_parameter("W", {"x": 0, "y": 0.5})

print("Before applying Prod5:")
hg.draw(use_positional_parameters=True)
# Out:
# Before applying Prod5:

# %%
prod5 = Prod5()
new_hg = prod5.apply(hg)

print("After applying Prod5:")
if new_hg:
    new_hg.draw(use_positional_parameters=True)
else:
    print("Production could not be applied.")
# Out:
# Average x: 0.5
# Average y: 0.5
# After applying Prod5:

# %%
from hypergrammar.hypergraph import Hypergraph
from hypergrammar.edge import Edge, EdgeType
from hypergrammar.productions.prod_5 import Prod5


hg = Hypergraph()
hg.set_vertex_parameter("A", {"x": 0, "y": 0})
hg.set_vertex_parameter("B", {"x": 1, "y": 0})
hg.set_vertex_parameter("C", {"x": 1, "y": 1})
hg.set_vertex_parameter("D", {"x": 0, "y": 1})
hg.set_vertex_parameter("X", {"x": 0.5, "y": 0})
hg.set_vertex_parameter("Y", {"x": 1, "y": 0.5})
hg.set_vertex_parameter("Z", {"x": 0.5, "y": 1})
hg.set_vertex_parameter("W", {"x": 0, "y": 0.5})
hg.set_vertex_parameter("M0", {"x": 0.5, "y": 0.5})

hg.set_vertex_parameter("P", {"x": 0.25, "y": 1})
hg.set_vertex_parameter("Q", {"x": 0, "y": 0.75})
hg.set_vertex_parameter("T", {"x": 0.25, "y": 0.5})
hg.set_vertex_parameter("R", {"x": 0.5, "y": 0.75})
hg.set_vertex_parameter("U", {"x": 0.75, "y": 1})
hg.set_vertex_parameter("G", {"x": 0.75, "y": 0.5})
hg.set_vertex_parameter("F", {"x": 1, "y": 0.75})
hg.set_vertex_parameter("M1", {"x": 0.75, "y": 0.75})

hg.add_edge(Edge(EdgeType.E, frozenset({"P", "D"}), {"B": 1, "R": 0}))
hg.add_edge(Edge(EdgeType.E, frozenset({"P", "Z"}), {"B": 1, "R": 0}))
hg.add_edge(Edge(EdgeType.E, frozenset({"Z", "R"}), {"B": 0, "R": 0}))
hg.add_edge(Edge(EdgeType.E, frozenset({"M0", "R"}), {"B": 0, "R": 0})) # tu
hg.add_edge(Edge(EdgeType.E, frozenset({"M0", "T"}), {"B": 0, "R": 0}))
hg.add_edge(Edge(EdgeType.E, frozenset({"W", "T"}), {"B": 1, "R": 0}))
hg.add_edge(Edge(EdgeType.E, frozenset({"D", "Q"}), {"B": 1, "R": 0}))
hg.add_edge(Edge(EdgeType.E, frozenset({"W", "Q"}), {"B": 1, "R": 0}))

hg.add_edge(Edge(EdgeType.E, frozenset({"Z", "U"}), {"B": 1, "R": 0}))
hg.add_edge(Edge(EdgeType.E, frozenset({"C", "U"}), {"B": 1, "R": 0}))
hg.add_edge(Edge(EdgeType.E, frozenset({"C", "F"}), {"B": 1, "R": 0}))
hg.add_edge(Edge(EdgeType.E, frozenset({"Y", "F"}), {"B": 1, "R": 0}))
hg.add_edge(Edge(EdgeType.E, frozenset({"M0", "G"}), {"B": 0, "R": 0}))
hg.add_edge(Edge(EdgeType.E, frozenset({"G", "Y"}), {"B": 0, "R": 0}))

hg.add_edge(Edge(EdgeType.Q, frozenset({"Z", "U", "R", "M1"}), {"R": 0}))
hg.add_edge(Edge(EdgeType.Q, frozenset({"C", "U", "M1", "F"}), {"R": 0}))
hg.add_edge(Edge(EdgeType.Q, frozenset({"M1", "F", "Y", "G"}), {"R": 0}))
hg.add_edge(Edge(EdgeType.Q, frozenset({"R", "M1", "G", "M0"}), {"R": 0}))

hg.add_edge(Edge(EdgeType.E, frozenset({"M1", "U"}), {"R": 0}))
hg.add_edge(Edge(EdgeType.E, frozenset({"M1", "F"}), {"R": 0}))
hg.add_edge(Edge(EdgeType.E, frozenset({"M1", "G"}), {"R": 0}))
hg.add_edge(Edge(EdgeType.E, frozenset({"M1", "R"}), {"R": 0}))

hg.add_edge(Edge(EdgeType.E, frozenset({"Y", "M0"}), {"R": 0}))
hg.add_edge(Edge(EdgeType.E, frozenset({"M0", "W"}), {"R": 0}))

hg.add_edge(Edge(EdgeType.E, frozenset({"M0", "X"})))

hg.add_edge(Edge(EdgeType.Q, frozenset({"M0", "W", "X", "A"}), {"R": 0}))  
hg.add_edge(Edge(EdgeType.Q, frozenset({"M0", "X", "Y", "B"}), {"R": 0}))
hg.add_edge(Edge(EdgeType.Q, frozenset({"M0", "Z", "W", "D"}), {"R": 1}))


hg.add_edge(Edge(EdgeType.E, frozenset({"A", "X"}), {"B": 1, "R": 0}))
hg.add_edge(Edge(EdgeType.E, frozenset({"X", "B"}), {"B": 1, "R": 0}))
hg.add_edge(Edge(EdgeType.E, frozenset({"B", "Y"}), {"B": 1, "R": 0}))
hg.add_edge(Edge(EdgeType.E, frozenset({"W", "A"}), {"B": 1, "R": 0}))

print("Before applying Prod5:")
hg.draw(use_positional_parameters=True)
# Out:
# Before applying Prod5:

# %%
prod5 = Prod5()
new_hg = prod5.apply(hg)

print("After applying Prod5:")
if new_hg:
    new_hg.draw(use_positional_parameters=True)
else:
    print("Production could not be applied.")
# Out:
# Average x: 0.25
# Average y: 0.75
# After applying Prod5:
